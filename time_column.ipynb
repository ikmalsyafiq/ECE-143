# %%
import pandas as pd
from itertools import chain
import collections

# %%
x = pd.read_csv('./survey_data.csv',sep = ',',header = 0) 
x.head()
# Out:
#        Timestamp    ID         What computer languages are you fluent in?  \
# 0  9/1/2017 7:21  3931  Matlab, JAVA, C/C++, Shell Scripts (BASH, CSH,...
# 1  9/1/2017 7:26  4205                                      Matlab, C/C++
# 2  9/1/2017 7:32  3669  Matlab, JAVA, C/C++, Shell Scripts (BASH, CSH,...
# 3  9/1/2017 7:39  1452     Matlab, C/C++, Shell Scripts (BASH, CSH, etc.)
# 4  9/1/2017 7:39  2968                                               None
#
#   What is your cumulative programming experience (in any language)?  \
# 0                                   More than 1 year
# 1                        Between 6 months and 1 year
# 2                                   More than 1 year
# 3                                   More than 1 year
# 4                        Between 6 months and 1 year
#
#   What is your desired technical role?  \
# 0                    Software engineer
# 1       Engineer (other than software)
# 2                       Data scientist
# 3                       Data scientist
# 4                                  Any
#
#   What platforms do you primarily work on?  \
# 0                               Linux/Unix
# 1                               Windows PC
# 2                               Windows PC
# 3                   Linux/Unix, Windows PC
# 4                   Linux/Unix, Windows PC
#
#   Do you have any prior Python programming experience?  \
# 0                                 More than 6 months
# 1                                               None
# 2                                 More than 6 months
# 3                                 More than 6 months
# 4                                 Less than 6 months
#
#   Are you interested in any particular Python packages?  \
# 0            scikit learn, Pandas, TensorFlow, Caffe
# 1                                               none
# 2                                 pandas, tensorflow
# 3  Don't really know which packages are offered o...
# 4                                       scikit learn
#
#   Is there anything in particular you want to use Python for?  \
# 0  Data extraction and processing, Data analytics...
# 1                     Data extraction and processing
# 2  Data analytics, Machine learning, Statistical ...
# 3  Data extraction and processing, Data analytics...
# 4  Numerical processing, Data analytics, Machine ...
#
#   How did you hear about this course?  \
# 0                    ECE Announcement
# 1                    ECE Announcement
# 2                    ECE Announcement
# 3                    ECE Announcement
# 4     Friend/Colleague recommended it
#
#   Is this class required for your degree program?  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   What are you hoping to learn from this class?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   If you are a graduate student, what is your current year of study?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   If you are a graduate student, what was your undergraduate institution?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Were you on the waiting list for this class for a previous quarter?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     Quarter
# 0  Fall2017
# 1  Fall2017
# 2  Fall2017
# 3  Fall2017
# 4  Fall2017

# %%
x['Timestamp_stamp'] =pd.to_datetime(x['Timestamp'], format='%m/%d/%Y %H:%M',dayfirst=True)

x['Month'] = x['Timestamp_stamp'].dt.month

import calendar
x['Month'] = x['Month'].apply(lambda x: calendar.month_abbr[x])
x
#x['Month'] = x['Month'].apply(lambda x: calendar.month_abbr[x])
x['Year'] = x['Timestamp_stamp'].dt.year
x['month-yr'] =  x["Month"] +'-'+x["Year"].astype(str)
x = x.drop(['Timestamp_stamp', 'Month', 'Year'], axis=1)
x
# Out:
#           Timestamp    ID         What computer languages are you fluent in?  \
# 0     9/1/2017 7:21  3931  Matlab, JAVA, C/C++, Shell Scripts (BASH, CSH,...
# 1     9/1/2017 7:26  4205                                      Matlab, C/C++
# 2     9/1/2017 7:32  3669  Matlab, JAVA, C/C++, Shell Scripts (BASH, CSH,...
# 3     9/1/2017 7:39  1452     Matlab, C/C++, Shell Scripts (BASH, CSH, etc.)
# 4     9/1/2017 7:39  2968                                               None
# ..              ...   ...                                                ...
# 481  1/8/2019 17:05  2052                                      Matlab, C/C++
# 482  1/8/2019 21:00  3767                                             Matlab
# 483  1/9/2019 13:18  3148                                      Matlab, C/C++
# 484  1/9/2019 17:02  1445                                      Matlab, C/C++
# 485  1/9/2019 17:04  2524                                      Matlab, C/C++
#
#     What is your cumulative programming experience (in any language)?  \
# 0                                     More than 1 year
# 1                          Between 6 months and 1 year
# 2                                     More than 1 year
# 3                                     More than 1 year
# 4                          Between 6 months and 1 year
# ..                                                 ...
# 481                                   More than 1 year
# 482                                 Less than 6 months
# 483                        Between 6 months and 1 year
# 484                                  More than 5 years
# 485                        Between 6 months and 1 year
#
#     What is your desired technical role?  \
# 0                      Software engineer
# 1         Engineer (other than software)
# 2                         Data scientist
# 3                         Data scientist
# 4                                    Any
# ..                                   ...
# 481                    Software engineer
# 482                       Data scientist
# 483                    Software engineer
# 484                    Software engineer
# 485       Engineer (other than software)
#
#     What platforms do you primarily work on?  \
# 0                                 Linux/Unix
# 1                                 Windows PC
# 2                                 Windows PC
# 3                     Linux/Unix, Windows PC
# 4                     Linux/Unix, Windows PC
# ..                                       ...
# 481         Linux/Unix, Windows PC, Mac OS X
# 482                     Linux/Unix, Mac OS X
# 483                                 Mac OS X
# 484                   Linux/Unix, Windows PC
# 485         Linux/Unix, Windows PC, Mac OS X
#
#     Do you have any prior Python programming experience?  \
# 0                                   More than 6 months
# 1                                                 None
# 2                                   More than 6 months
# 3                                   More than 6 months
# 4                                   Less than 6 months
# ..                                                 ...
# 481                                 Less than 6 months
# 482                           None, Less than 6 months
# 483                                 Less than 6 months
# 484                                 Less than 6 months
# 485                                               None
#
#     Are you interested in any particular Python packages?  \
# 0              scikit learn, Pandas, TensorFlow, Caffe
# 1                                                 none
# 2                                   pandas, tensorflow
# 3    Don't really know which packages are offered o...
# 4                                         scikit learn
# ..                                                 ...
# 481                                      pandas, keras
# 482                                              Numpy
# 483                          Numpy, Pandas, Matplotlib
# 484                                      Numpy, scikit
# 485                                              Numpy
#
#     Is there anything in particular you want to use Python for?  \
# 0    Data extraction and processing, Data analytics...
# 1                       Data extraction and processing
# 2    Data analytics, Machine learning, Statistical ...
# 3    Data extraction and processing, Data analytics...
# 4    Numerical processing, Data analytics, Machine ...
# ..                                                 ...
# 481  Scientific visualization, Data extraction and ...
# 482  Numerical processing, Scientific visualization...
# 483  Data extraction and processing, Machine learni...
# 484                     Data extraction and processing
# 485  Data extraction and processing, Data analytics...
#
#     How did you hear about this course?  \
# 0                      ECE Announcement
# 1                      ECE Announcement
# 2                      ECE Announcement
# 3                      ECE Announcement
# 4       Friend/Colleague recommended it
# ..                                  ...
# 481     Friend/Colleague recommended it
# 482                    ECE Announcement
# 483     Friend/Colleague recommended it
# 484     Friend/Colleague recommended it
# 485                    ECE Announcement
#
#     Is this class required for your degree program?  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 481                                             Yes
# 482                                             Yes
# 483                                              No
# 484                                              No
# 485                                              No
#
#          What are you hoping to learn from this class?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                              Some smart algorithms
# 482  Obtain proficiency in python programming langu...
# 483                             a better use of Python
# 484  Become comfortable with python for scripting/d...
# 485                        Python and machine learning
#
#     If you are a graduate student, what is your current year of study?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                        First year graduate student
# 482                        First year graduate student
# 483                        First year graduate student
# 484                       Second year graduate student
# 485                        First year graduate student
#
#     If you are a graduate student, what was your undergraduate institution?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                                  Purdue University
# 482                                               UCSD
# 483                    Beijing Institute of Technology
# 484                             Anna University, India
# 485                                           UC Davis
#
#     Were you on the waiting list for this class for a previous quarter?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                                                Yes
# 482                                                 No
# 483                                                 No
# 484                                                 No
# 485                                                 No
#
#       Quarter  month-yr
# 0    Fall2017  Sep-2017
# 1    Fall2017  Sep-2017
# 2    Fall2017  Sep-2017
# 3    Fall2017  Sep-2017
# 4    Fall2017  Sep-2017
# ..        ...       ...
# 481       NaN  Jan-2019
# 482       NaN  Jan-2019
# 483       NaN  Jan-2019
# 484       NaN  Jan-2019
# 485       NaN  Jan-2019
#
# [486 rows x 17 columns]

# %%
import calendar
import pandas as pd
def add_month_yr(x):
    """add month and year column

    Args:
        x (dataframe): dataframe

    Returns:
        dataframe: dataframe with month-yr column
    """    
    assert isinstance(x,pd.DataFrame)
    x['Timestamp_stamp'] =pd.to_datetime(x['Timestamp'], format='%m/%d/%Y %H:%M',dayfirst=True)
    x['Month'] = x['Timestamp_stamp'].dt.month
    x['Month'] = x['Month'].apply(lambda x: calendar.month_abbr[x])
    x['Year'] = x['Timestamp_stamp'].dt.year
    x['month-yr'] =  x["Month"] +'-'+x["Year"].astype(str)
    x = x.drop(['Timestamp_stamp', 'Month', 'Year'], axis=1)
    return x

# %%
y = pd.read_csv('./survey_data.csv',sep = ',',header = 0) 
add_month_yr(y)
# Out:
#           Timestamp    ID         What computer languages are you fluent in?  \
# 0     9/1/2017 7:21  3931  Matlab, JAVA, C/C++, Shell Scripts (BASH, CSH,...
# 1     9/1/2017 7:26  4205                                      Matlab, C/C++
# 2     9/1/2017 7:32  3669  Matlab, JAVA, C/C++, Shell Scripts (BASH, CSH,...
# 3     9/1/2017 7:39  1452     Matlab, C/C++, Shell Scripts (BASH, CSH, etc.)
# 4     9/1/2017 7:39  2968                                               None
# ..              ...   ...                                                ...
# 481  1/8/2019 17:05  2052                                      Matlab, C/C++
# 482  1/8/2019 21:00  3767                                             Matlab
# 483  1/9/2019 13:18  3148                                      Matlab, C/C++
# 484  1/9/2019 17:02  1445                                      Matlab, C/C++
# 485  1/9/2019 17:04  2524                                      Matlab, C/C++
#
#     What is your cumulative programming experience (in any language)?  \
# 0                                     More than 1 year
# 1                          Between 6 months and 1 year
# 2                                     More than 1 year
# 3                                     More than 1 year
# 4                          Between 6 months and 1 year
# ..                                                 ...
# 481                                   More than 1 year
# 482                                 Less than 6 months
# 483                        Between 6 months and 1 year
# 484                                  More than 5 years
# 485                        Between 6 months and 1 year
#
#     What is your desired technical role?  \
# 0                      Software engineer
# 1         Engineer (other than software)
# 2                         Data scientist
# 3                         Data scientist
# 4                                    Any
# ..                                   ...
# 481                    Software engineer
# 482                       Data scientist
# 483                    Software engineer
# 484                    Software engineer
# 485       Engineer (other than software)
#
#     What platforms do you primarily work on?  \
# 0                                 Linux/Unix
# 1                                 Windows PC
# 2                                 Windows PC
# 3                     Linux/Unix, Windows PC
# 4                     Linux/Unix, Windows PC
# ..                                       ...
# 481         Linux/Unix, Windows PC, Mac OS X
# 482                     Linux/Unix, Mac OS X
# 483                                 Mac OS X
# 484                   Linux/Unix, Windows PC
# 485         Linux/Unix, Windows PC, Mac OS X
#
#     Do you have any prior Python programming experience?  \
# 0                                   More than 6 months
# 1                                                 None
# 2                                   More than 6 months
# 3                                   More than 6 months
# 4                                   Less than 6 months
# ..                                                 ...
# 481                                 Less than 6 months
# 482                           None, Less than 6 months
# 483                                 Less than 6 months
# 484                                 Less than 6 months
# 485                                               None
#
#     Are you interested in any particular Python packages?  \
# 0              scikit learn, Pandas, TensorFlow, Caffe
# 1                                                 none
# 2                                   pandas, tensorflow
# 3    Don't really know which packages are offered o...
# 4                                         scikit learn
# ..                                                 ...
# 481                                      pandas, keras
# 482                                              Numpy
# 483                          Numpy, Pandas, Matplotlib
# 484                                      Numpy, scikit
# 485                                              Numpy
#
#     Is there anything in particular you want to use Python for?  \
# 0    Data extraction and processing, Data analytics...
# 1                       Data extraction and processing
# 2    Data analytics, Machine learning, Statistical ...
# 3    Data extraction and processing, Data analytics...
# 4    Numerical processing, Data analytics, Machine ...
# ..                                                 ...
# 481  Scientific visualization, Data extraction and ...
# 482  Numerical processing, Scientific visualization...
# 483  Data extraction and processing, Machine learni...
# 484                     Data extraction and processing
# 485  Data extraction and processing, Data analytics...
#
#     How did you hear about this course?  \
# 0                      ECE Announcement
# 1                      ECE Announcement
# 2                      ECE Announcement
# 3                      ECE Announcement
# 4       Friend/Colleague recommended it
# ..                                  ...
# 481     Friend/Colleague recommended it
# 482                    ECE Announcement
# 483     Friend/Colleague recommended it
# 484     Friend/Colleague recommended it
# 485                    ECE Announcement
#
#     Is this class required for your degree program?  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 481                                             Yes
# 482                                             Yes
# 483                                              No
# 484                                              No
# 485                                              No
#
#          What are you hoping to learn from this class?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                              Some smart algorithms
# 482  Obtain proficiency in python programming langu...
# 483                             a better use of Python
# 484  Become comfortable with python for scripting/d...
# 485                        Python and machine learning
#
#     If you are a graduate student, what is your current year of study?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                        First year graduate student
# 482                        First year graduate student
# 483                        First year graduate student
# 484                       Second year graduate student
# 485                        First year graduate student
#
#     If you are a graduate student, what was your undergraduate institution?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                                  Purdue University
# 482                                               UCSD
# 483                    Beijing Institute of Technology
# 484                             Anna University, India
# 485                                           UC Davis
#
#     Were you on the waiting list for this class for a previous quarter?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 481                                                Yes
# 482                                                 No
# 483                                                 No
# 484                                                 No
# 485                                                 No
#
#       Quarter  month-yr
# 0    Fall2017  Sep-2017
# 1    Fall2017  Sep-2017
# 2    Fall2017  Sep-2017
# 3    Fall2017  Sep-2017
# 4    Fall2017  Sep-2017
# ..        ...       ...
# 481       NaN  Jan-2019
# 482       NaN  Jan-2019
# 483       NaN  Jan-2019
# 484       NaN  Jan-2019
# 485       NaN  Jan-2019
#
# [486 rows x 17 columns]

# %%
x['mnth_yr'] = x['Timestamp'].apply(lambda y: y.strftime('%B-%Y'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ddcb7c1db27c> in <module>
# ----> 1 x['mnth_yr'] = x['Timestamp'].apply(lambda y: y.strftime('%B-%Y'))
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
# -> 1102                     convert=self.convert_dtype,
#    1103                 )
#    1104
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-6-ddcb7c1db27c> in <lambda>(y)
# ----> 1 x['mnth_yr'] = x['Timestamp'].apply(lambda y: y.strftime('%B-%Y'))
#
# AttributeError: 'str' object has no attribute 'strftime'
