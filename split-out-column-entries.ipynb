# %%
import pandas as pd
from itertools import chain
import collections

# %%
x = pd.read_csv('./survey_data.csv',sep = ',',header = 0)

# %%
splitted = []
for i in x['Is there anything in particular you want to use Python for?']:
    splitted.append(i.split(','))

# %%
y = list(chain.from_iterable(splitted))
#print()
counter=collections.Counter(y)
counter
data = pd.DataFrame(counter.items())
data = data.rename(columns={0: '', 1: 'Count'})
data = data.sort_values(by = ['Count'],ascending=True)
data.reset_index(drop=True, inplace=True)
data
# Out:
#                                                Count
# 0                                   EDA tools      1
# 1                                    not sure      1
# 2    scripting seems desirable for many jobs       1
# 3                          As a general skill      1
# 4            Computer vision/image processing      1
# 5                            All of the above      1
# 6                            Image Processing      1
# 7                             Computer Vision      1
# 8                             Computer vision      1
# 9                        Statistical analysis      3
# 10                            Web development      5
# 11                           Machine learning     41
# 12                             Data analytics     76
# 13                   Scientific visualization     87
# 14             Data extraction and processing     99
# 15                            Web development     99
# 16                   Scientific visualization    111
# 17                       Numerical processing    173
# 18             Data extraction and processing    192
# 19                       Statistical analysis    219
# 20                             Data analytics    275
# 21                           Machine learning    340

# %%
def  split_count(x):
    assert isinstance(x,pd.Series)
    splitted = []
    for i in x['Is there anything in particular you want to use Python for?']:
        splitted.append(i.split(','))
        y = list(chain.from_iterable(splitted))
    #print()
    counter=collections.Counter(y)
    counter
    data = pd.DataFrame(counter.items())
    data = data.rename(columns={0: '', 1: 'Count'})
    data = data.sort_values(by = ['Count'],ascending=True)
    data.reset_index(drop=True, inplace=True)
    return data

# %%
import pandas as pd
from itertools import chain
import collections

def  split_count(x):
    """split out column entries

    Args:
        x (dataframe): dataframe

    Returns:
        dataframe: dataframe with count
    """    
    assert isinstance(x,pd.Series)
    splitted = []
    for i in x:
        splitted.append(i.split(', '))
        y = list(chain.from_iterable(splitted))
    #print()
    counter=collections.Counter(y)
    counter
    data = pd.DataFrame(counter.items())
    data = data.rename(columns={0: '', 1: 'Count'})
    data = data.sort_values(by = ['Count'],ascending=True)
    data.reset_index(drop=True, inplace=True)
    data = data.set_index('')
    return data

x = pd.read_csv('./survey_data.csv',sep = ',',header = 0) 
print(split_count(x['Is there anything in particular you want to use Python for?']))
# Out:
#                                           Count
#
# All of the above                              1
# Computer vision                               1
# Image Processing                              1
# Computer vision/image processing              1
# As a general skill                            1
# scripting seems desirable for many jobs       1
# not sure                                      1
# Computer Vision                               1
# EDA tools                                     1
# Web development                             104
# Numerical processing                        173
# Scientific visualization                    198
# Statistical analysis                        222
# Data extraction and processing              291
# Data analytics                              351
# Machine learning                            381
