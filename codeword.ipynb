# %%
import numpy as np
import string
from string import punctuation

# %%
def file_read(fname):
        content_array = []
        with open(fname) as f:
                #Content_list is the list that contains the read lines.     
                for line in f:
                
                        line_here = (line.lower().strip(punctuation).split(" "))
                        line_here = np.array(line_here)
                        
                        content_array.append(line_here)
                
                array = np.array(content_array)
                return array

a = file_read('chucktest.txt')
print(a)
# Out:
# [array(['one', 'morning,', 'when', 'gregor', 'samsa', 'woke', 'from',
#         'troubled', 'dreams,', 'he', 'found\n'], dtype='<U8')
#  array(['himself', 'transformed', 'in', 'his', 'bed', 'into', 'a',
#         'horrible', 'vermin.', '', 'he', 'lay', 'on\n'], dtype='<U11')
#  array(['his', 'armour-like', 'back,', 'and', 'if', 'he', 'lifted', 'his',
#         'head', 'a', 'little', 'he', 'could\n'], dtype='<U11')
#  array(['see', 'his', 'brown', 'belly,', 'slightly', 'domed', 'and',
#         'divided', 'by', 'arches', 'into', 'stiff\n'], dtype='<U8')
#  array(['sections.', '', 'the', 'bedding', 'was', 'hardly', 'able', 'to',
#         'cover', 'it', 'and', 'seemed', 'ready\n'], dtype='<U9')
#  array(['to', 'slide', 'off', 'any', 'moment.', '', 'his', 'many', 'legs,',
#         'pitifully', 'thin', 'compared\n'], dtype='<U9')
#  array(['with', 'the', 'size', 'of', 'the', 'rest', 'of', 'him,', 'waved',
#         'about', 'helplessly', 'as', 'he\n'], dtype='<U10')
# ...

# %%
words = 'a lay four gregor'
words_array = np.array(words.strip(punctuation).split(" "))
words_array
# Out:
# array(['a', 'lay', 'four', 'gregor'], dtype='<U6')

# %%
if 'one' in a:
    print(True)
else:
    print(False)

# %%
tuple_code = []
#print(a[0,0])
for li in words_array:
    list_of_words = []
    for index, x in np.ndenumerate(a):
        #print(index, x)
        
        x[0]
        for index_2, y in np.ndenumerate(x):
           # print(index[0])
           # print(index_2[0])
            
            if a[index[0]][index_2[0]] == li:
                tuple_match = (index[0],index_2[0])
                if tuple_match not in list:
                    print(tuple_match)
                    list_of_words.append(tuple_match)
                    break
                    #breaking = breaking+1
        
            if len(list_of_words) != 0:
        
                print(list_of_words) 
                print('z')           
        #if len(list_of_words) != 0:
            
        
                
tuple_code
# Out:
# (1, 6)
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# (2, 9)
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# ...

# %%
xxx = []
for i,j in tuple_code:
    print(i,j)
    print(a[i][j])
    xxx.append(a[i][j])

set(xxx)
# Out:
# set()

# %%
tuple_code
# Out:
# [(1, 6),
#  (2, 9),
#  (9, 9),
#  (10, 0),
#  (11, 6),
#  (12, 9),
#  (13, 4),
#  (14, 5),
#  (15, 0),
#  (16, 1),
#  (1, 11),
#  (10, 9),
#  (12, 0),
#  (11, 2)]

# %%
    for index, x in np.ndenumerate(a):
        #print(index, x)
        #print(x[index][0])
        print(type(x[0]))
        #print(index_2,y)
        m = (index[0],index_2[0])
        
        #print(m)
# Out:
#   File "<ipython-input-129-974c32d84000>", line 2
#     for index, x in np.ndenumerate(a):
#     ^
# IndentationError: unexpected indent
