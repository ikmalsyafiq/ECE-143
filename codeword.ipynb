# %%
import numpy as np
import string
from string import punctuation
import random

# %%
def file_read(fname):
        content_array = []
        with open(fname) as f:
                #Content_list is the list that contains the read lines.     
                for line in f:
                
                        line_here = (line.lower().strip(punctuation).strip().split(" "))
                        line_here = [''.join(c for c in s if c not in string.punctuation) for s in line_here]
                        line_here = np.array(line_here)
                        
                        content_array.append(line_here)
                
                array = np.array(content_array)
                return array

a = file_read('textfilechunkify.txt')
print(a)
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'metamorphosis', 'by', 'franz', 'kafka']
# ['translated', 'by', 'david', 'wyllie']
# ['']
# ['this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with']
# ['almost', 'no', 'restrictions', 'whatsoever', '', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or']
# ['reuse', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included']
# ['with', 'this', 'ebook', 'or', 'online', 'at', 'wwwgutenbergnet']
# ['']
# ['this', 'is', 'a', 'copyrighted', 'project', 'gutenberg', 'ebook', 'details', 'below', '']
# ['please', 'follow', 'the', 'copyright', 'guidelines', 'in', 'this', 'file', '', '', '', '', '']
# ['']
# ['']
# ['title', 'metamorphosis']
# ['']
# ['author', 'franz', 'kafka']
# ['']
# ['translator', 'david', 'wyllie']
# ['']
# ['release', 'date', 'august', '16', '2005', 'ebook', '5200']
# ['first', 'posted', 'may', '13', '2002']
# ...

# %%
words = 'let us not say we met late at the night about the secret '
words_array = np.array(words.strip(punctuation).split(" "))
words_array
# Out:
# array(['let', 'us', 'not', 'say', 'we', 'met', 'late', 'at', 'the',
#        'night', 'about', 'the', 'secret', ''], dtype='<U6')

# %%
if 'one' in a:
    print(True)
else:
    print(False)

# %%
tuple_code = []
#print(a[0,0])
for li in words_array:
    list_of_words = []
    for index, x in np.ndenumerate(a):
        #print(index, x)
        
        x[0]
        for index_2, y in np.ndenumerate(x):
           # print(index[0])
           # print(index_2[0])
            
            if a[index[0]][index_2[0]] == li:
                tuple_match = (index[0],index_2[0])
                if tuple_match not in list:
                    print(tuple_match)
                    list_of_words.append(tuple_match)
                    break
                    #breaking = breaking+1
        
            if len(list_of_words) != 0:
        
                print(list_of_words) 
                print('z')           
        #if len(list_of_words) != 0:
            
        
                
tuple_code
# Out:
# (1, 6)
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# [(1, 6)]
# z
# (2, 9)
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# z
# [(1, 6), (2, 9)]
# ...

# %%
tuple_code = []
#print(a[0,0])
for li in words_array:
    list_of_words = []
    for index, x in np.ndenumerate(a):
        #print(index[0])
        #print(type(x))
        #print(x == li])
        if li in x:
            mnm = np.where(x==li)
            #print(np.where(x==li))
            #print(index[0],mnm[0][0])
            list_of_words.append((index[0],mnm[0][0]))
    #print(list_of_words)
    tuple_code.append(list_of_words)

        
tuple_code
# Out:
# [[(101, 3),
#   (209, 9),
#   (278, 1),
#   (335, 13),
#   (342, 6),
#   (383, 8),
#   (397, 8),
#   (407, 12),
#   (448, 2),
#   (515, 9),
#   (558, 10),
#   (575, 3),
#   (855, 3),
#   (907, 8),
#   (954, 4),
#   (1035, 0),
#   (1072, 7),
#   (1110, 10),
#   (1138, 4),
#   (1393, 1),
#   (1649, 12),
#   (1658, 10),
#   (1682, 5),
#   (1796, 3)],
#  [(313, 8),
#   (351, 10),
#   (1100, 11),
#   (1596, 7),
#   (1727, 3),
#   (1774, 3),
#   (1878, 3),
#   (2329, 1)],
#  [(114, 11),
#   (118, 3),
#   (121, 6),
#   (123, 4),
#   (125, 8),
#   (132, 2),
#   (151, 9),
#   (173, 3),
#   (177, 7),
#   (210, 6),
#   (211, 11),
#   (220, 1),
#   (222, 10),
#   (257, 9),
#   (267, 1),
#   (274, 6),
#   (277, 10),
#   (287, 5),
#   (322, 9),
#   (333, 5),
#   (334, 6),
#   (335, 7),
#   (339, 9),
#   (344, 7),
#   (363, 3),
#   (368, 8),
#   (370, 1),
#   (378, 13),
#   (413, 3),
#   (437, 5),
#   (440, 4),
#   (476, 3),
#   (492, 3),
#   (516, 9),
#   (548, 8),
#   (559, 13),
#   (571, 9),
# ...

# %%
coded_messages = []
for i in tuple_code:
    is_true = True
    while (is_true):
        assert len(i) != 0
        x_rand = random.choice(i)
        if x_rand not in coded_messages:
            coded_messages.append(x_rand)
            is_true = False

coded_messages
# Out:
# [(558, 10),
#  (313, 8),
#  (1454, 4),
#  (1023, 1),
#  (541, 0),
#  (1191, 5),
#  (731, 4),
#  (1070, 3),
#  (421, 8),
#  (1433, 6),
#  (1091, 9),
#  (1389, 5),
#  (551, 4),
#  (305, 6)]

# %%
decrypted_messages = []
for ic in coded_messages:
    decrypted_messages.append(a[ic[0]][ic[1]])

' '.join(decrypted_messages)
# Out:
# 'let us not say we met late at the night about the secret '

# %%
xxx = []
for i,j in tuple_code:
    print(i,j)
    print(a[i][j])
    xxx.append(a[i][j])

set(xxx)
# Out:
# set()

# %%
tuple_code
# Out:
# [(1, 6),
#  (2, 9),
#  (9, 9),
#  (10, 0),
#  (11, 6),
#  (12, 9),
#  (13, 4),
#  (14, 5),
#  (15, 0),
#  (16, 1),
#  (1, 11),
#  (10, 9),
#  (12, 0),
#  (11, 2)]

# %%
def encrypt_message(message,fname):
    '''
  Given `message`, which is a lowercase string without any punctuation, and `fname` which is the
  name of a text file source for the codebook, generate a sequence of 2-tuples that
  represents the `(line number, word number)` of each word in the message. The output is a list
  of 2-tuples for the entire message. Repeated words in the message should not have the same 2-tuple. 
  7     
  :param message: message to encrypt
  :type message: str
 :param fname: filename for source text
 :type fname: str
 :returns: list of 2-tuples
   '''

    def file_read(fname):
        content_array = []
        with open(fname) as f:
                #Content_list is the list that contains the read lines.     
                for line in f:
                
                        line_here = (line.lower().strip(punctuation).strip().split(" "))
                        line_here = [''.join(c for c in s if c not in string.punctuation) for s in line_here]
                        line_here = np.array(line_here)
                        
                        content_array.append(line_here)
                
                array = np.array(content_array)
                return array
    
    a = file_read(fname)
    words = message
    words_array = np.array(words.strip(punctuation).split(" "))

    tuple_code = []
    #print(a[0,0])
    for li in words_array:
        list_of_words = []
        for index, x in np.ndenumerate(a):
        #print(index[0])
        #print(type(x))
        #print(x == li])
            if li in x:
                mnm = np.where(x==li)
            #print(np.where(x==li))
            #print(index[0],mnm[0][0])
                list_of_words.append((index[0],mnm[0][0]))
    #print(list_of_words)
        tuple_code.append(list_of_words)
    
    coded_messages = []
    for i in tuple_code:
        is_true = True
        while (is_true):
            assert len(i) != 0
            x_rand = i.pop()
            #print(x_rand)
            if x_rand not in coded_messages :
                coded_messages.append(x_rand)
                is_true = False
            
    #print(coded_messages)
    return coded_messages


def decrypt_message(inlist,fname):
    '''
     Given `inlist`, which is a list of 2-tuples`fname` which is the
     name of a text file source for the codebook, return the encrypted message. 
     
     :param message: inlist to decrypt
     :type message: list
     :param fname: filename for source text
     :type fname: str
     :returns: string decrypted message
    '''
    
    def file_read(fname):
        content_array = []
        with open(fname) as f:
                #Content_list is the list that contains the read lines.     
                for line in f:
                
                        line_here = (line.lower().strip(punctuation).strip().split(" "))
                        line_here = [''.join(c for c in s if c not in string.punctuation) for s in line_here]
                        line_here = np.array(line_here)
                        
                        content_array.append(line_here)
                
                array = np.array(content_array)
                return array
    
    a = file_read(fname)
    
    decrypted_messages = []
    for ic in inlist:
        decrypted_messages.append(a[ic[0]][ic[1]])

    decrypted_string = ' '.join(decrypted_messages)
    return decrypted_string
    
    

words = 'let us not '
mmmmm = encrypt_message(words,'chucktest.txt')
#print(mmmmm)

print(decrypt_message(mmmmm,'chucktest.txt'))
# Out:
# /Users/ikmalmahadi/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/ipykernel_launcher.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-274-6b05a92362b1> in <module>
#     102
#     103 words = 'let us not say we met late at the night about the secret '
# --> 104 mmmmm = encrypt_message(words,'chucktest.txt')
#     105 #print(mmmmm)
#     106
#
# <ipython-input-274-6b05a92362b1> in encrypt_message(message, fname)
#      52         is_true = True
#      53         while (is_true):
# ---> 54             assert len(i) != 0
#      55             x_rand = i.pop()
# ...
